# %% [markdown]
# In this notebook we will explore the traces.
# We look at what kind of values appear for the different fields.
# Also we hypothesize that there are some redundant field. So we will try to verify this.

# %%
import os
import sys
sys.path.append("../../src")
from features import trace_pre_processing as tpp
import json
from collections import Counter

# %%
# Lets find the paths to all the traces
trace_paths = []
for path_to_traces in ['../../data/raw/sequential_data/traces','../../data/raw/concurrent_data/traces']:
    trace_paths.extend([os.path.join(dp, f) for dp, dn, filenames in os.walk(path_to_traces) for f in filenames if os.path.splitext(f)[1] == '.json'])

# %%
# This method collects attributes values from the events using the collect_function. It does that for all the available events and returns them either as a list or a set depending on the parameter unique.
def find_attribute_values(collect_function, unique=False):
    occuring_values = list()
    for trace_path in trace_paths:
        with open(trace_path) as trace_file:
            trace_json = json.load(trace_file)
            values_for_trace = tpp.get_flat_list(trace_json,collect_function)
            occuring_values.extend(values_for_trace)
    if unique:
        return list(filter(lambda x: x != None, set(occuring_values)))
    else:
        return list(filter(lambda x: x != None, occuring_values))


# This method prints the elements
def print_information(values, msg='Information about the values in the list:', print_counts = True):
    print(msg)
    print('A total of ' + str(len(values)) + ' values were collected')
    if print_counts:
        counts = Counter(values).items()
        print('A total of ' + str(len(counts)) + ' unique values were collected')
        for e, c in sorted(counts, key=lambda x: x[1], reverse=True):
            print(str(c) + ' times: ' + str(e))
    else:
        for v in values:
            print(str(v))

# %% [markdown]
# First of all we are interested in some of the basic attributes of events

# %%
def collect_interesting_attributes(event):
    return [
        [
            event['info'].get('name'), 
            event['info'].get('service'), 
            event['info'].get('project'), 
            event['info'].get('exception'),
            event['info'].get('host')
        ]
    ]

basic_event_attributes = find_attribute_values(collect_interesting_attributes)
print_information(list(map(lambda x: x[0], basic_event_attributes)), 'Information about the name field')
print_information(list(map(lambda x: x[1], basic_event_attributes)), '\nInformation about the service field')
print_information(list(map(lambda x: x[2], basic_event_attributes)), '\nInformation about the project field')
print_information(list(map(lambda x: x[3], basic_event_attributes)), '\nInformation about the exception field')
print_information(list(map(lambda x: x[4], basic_event_attributes)), '\nInformation about the host field')
# Out:
# Information about the name field
# A total of 2519693 values were collected
# A total of 7 unique values were collected
# 979001 times: neutron.db
# 659774 times: db
# 592508 times: neutron_api
# 167904 times: wsgi
# 77706 times: rpc
# 40648 times: compute_api
# 2152 times: nova_image
#
# Information about the service field
# A total of 2519693 values were collected
# A total of 8 unique values were collected
# 1033490 times: neutron-server
# 633158 times: osapi_compute
# 286439 times: public
# 245013 times: api
# 243224 times: nova-conductor
# 47153 times: nova-compute
# 25073 times: nova-scheduler
# 6143 times: neutron-dhcp-agent
#
# Information about the project field
# A total of 2519693 values were collected
# A total of 4 unique values were collected
# 1039633 times: neutron
# 948608 times: nova
# 286439 times: keystone
# 245013 times: glance
#
# Information about the exception field
# A total of 2519693 values were collected
# A total of 5 unique values were collected
# 2514661 times: None
# 4060 times: keystoneauth1.exceptions.connection.ConnectFailure
# 866 times: nova.exception.InstanceNotFound
# 70 times: None
# 36 times: nova.exception.GlanceConnectionFailed
#
# Information about the host field
# A total of 2519693 values were collected
# A total of 5 unique values were collected
# 2472540 times: wally113
# 15944 times: wally122
# 11234 times: wally117
# 10073 times: wally124
# 9902 times: wally123

# %% [markdown]
# Lets look at some of the combinations of these attributes as well:

# %%
print_information(list(map(lambda x: (x[0], x[1]), basic_event_attributes)), 'Information about the combination of the name and service field')
print_information(list(map(lambda x: (x[0], x[4]), basic_event_attributes)), '\nInformation about the combination of the name and host field')
print_information(list(map(lambda x: (x[1], x[4]), basic_event_attributes)), '\nInformation about the combination of the service and host field')
# Out:
# Information about the combination of the name and service field
# A total of 2519693 values were collected
# A total of 19 unique values were collected
# 979001 times: ('neutron.db', 'neutron-server')
# 551189 times: ('neutron_api', 'osapi_compute')
# 238350 times: ('db', 'public')
# 217419 times: ('db', 'api')
# 203695 times: ('db', 'nova-conductor')
# 54489 times: ('wsgi', 'neutron-server')
# 48089 times: ('wsgi', 'public')
# 41319 times: ('neutron_api', 'nova-compute')
# 40648 times: ('compute_api', 'osapi_compute')
# 39529 times: ('rpc', 'nova-conductor')
# 37732 times: ('wsgi', 'osapi_compute')
# 27594 times: ('wsgi', 'api')
# 24763 times: ('rpc', 'nova-scheduler')
# 6143 times: ('rpc', 'neutron-dhcp-agent')
# 5830 times: ('rpc', 'nova-compute')
# 2148 times: ('nova_image', 'osapi_compute')
# 1441 times: ('rpc', 'osapi_compute')
# 310 times: ('db', 'nova-scheduler')
# 4 times: ('nova_image', 'nova-compute')
#
# Information about the combination of the name and host field
# A total of 2519693 values were collected
# A total of 16 unique values were collected
# 979001 times: ('neutron.db', 'wally113')
# 659774 times: ('db', 'wally113')
# 551189 times: ('neutron_api', 'wally113')
# 167904 times: ('wsgi', 'wally113')
# 71876 times: ('rpc', 'wally113')
# 40648 times: ('compute_api', 'wally113')
# 13972 times: ('neutron_api', 'wally122')
# 9856 times: ('neutron_api', 'wally117')
# 8817 times: ('neutron_api', 'wally124')
# 8674 times: ('neutron_api', 'wally123')
# 2148 times: ('nova_image', 'wally113')
# 1972 times: ('rpc', 'wally122')
# 1378 times: ('rpc', 'wally117')
# 1252 times: ('rpc', 'wally124')
# 1228 times: ('rpc', 'wally123')
# 4 times: ('nova_image', 'wally124')
#
# Information about the combination of the service and host field
# A total of 2519693 values were collected
# A total of 11 unique values were collected
# 1033490 times: ('neutron-server', 'wally113')
# 633158 times: ('osapi_compute', 'wally113')
# 286439 times: ('public', 'wally113')
# 245013 times: ('api', 'wally113')
# 243224 times: ('nova-conductor', 'wally113')
# 25073 times: ('nova-scheduler', 'wally113')
# 15944 times: ('nova-compute', 'wally122')
# 11234 times: ('nova-compute', 'wally117')
# 10073 times: ('nova-compute', 'wally124')
# 9902 times: ('nova-compute', 'wally123')
# 6143 times: ('neutron-dhcp-agent', 'wally113')

# %% [markdown]
# Lets have a closer look at the payload attribute
# My observation is that events contain two fields holding payload data: meta_raw_payload.name-start and meta_raw_payload.name-stop
# We need to verify that every event contains both fields.

# %%
def is_event_empty_or_top_level(event):
    return len(event) == 0 or event['info']['name'] == 'total'

def get_payload_start_name(event):
    return 'meta.raw_payload.' + event['info']['name'] + '-start'

def get_payload_stop_name(event):
    return 'meta.raw_payload.' + event['info']['name'] + '-stop'

def does_event_contain_both_payload_fields(event):
    return event['info'].get(get_payload_start_name(event)) != None and event['info'].get(get_payload_stop_name(event)) != None

def collect_trace_ids_for_events_that_dont_have_both_payload_fields(event):
    if is_event_empty_or_top_level(event) or does_event_contain_both_payload_fields(event): return [None] 
    return [(event['info']['name'], event['trace_id'], event['info'].get('service'))]

print_information(find_attribute_values(collect_trace_ids_for_events_that_dont_have_both_payload_fields, unique=True), msg="Events that don't contain both payload fields", print_counts=False)
# Out:
# Events that don't contain both payload fields
# A total of 70 values were collected
# ('wsgi', '4434e85d-a739-4e53-abb1-eb8f61becdbc', 'neutron-server')
# ('wsgi', 'cf9d2296-09aa-43bc-a983-472c429b9be7', 'api')
# ('wsgi', '36008481-29ca-47d5-9268-27b9549cebf4', 'api')
# ('wsgi', '3587372d-d48c-4826-9780-c1ef3d547515', 'api')
# ('wsgi', '88af3ac3-d3a9-43b8-8663-aca75b20e0ba', 'api')
# ('neutron.db', '2a8305fe-4141-4c83-8976-82bd3e250637', 'neutron-server')
# ('wsgi', '92ab4b65-0db6-451b-8203-1a4f8d7e6838', 'neutron-server')
# ('wsgi', 'cbbc0733-2a24-42c6-a6c0-9429c3212f16', 'neutron-server')
# ('neutron.db', '2aa71ef7-5f96-4997-ab4f-69e14b2f78be', 'neutron-server')
# ('wsgi', '6d1677ec-39f5-4fa3-8852-c7c15f078ab4', 'api')
# ('wsgi', '3ab8b155-010d-4688-be5c-ae12bbc40d29', 'api')
# ('wsgi', '2de4db85-7446-4c9d-b958-0312b714491d', 'api')
# ('wsgi', 'eb18b4ec-e6c6-4e0b-92ee-cb36184b799f', 'api')
# ('db', 'f38a99fc-c5f5-4863-9f6e-4febb095ea76', 'api')
# ('wsgi', '3124750e-90e6-44db-804d-a0fe411ed218', 'neutron-server')
# ('wsgi', '2798264b-5f76-4113-a343-791ca41553e1', 'api')
# ('wsgi', '3bae4912-2f01-4ad7-b317-ffcbef561ac3', 'neutron-server')
# ('wsgi', '074c806b-edce-4995-80e2-e155d6c03bc9', 'api')
# ('wsgi', '158f7cf9-a7fe-4921-ae9c-f06187014b52', 'api')
# ('neutron.db', '08542bfd-7cb8-4e01-8522-a33b682bac4c', 'neutron-server')
# ('wsgi', 'fbd49d7c-e063-40bd-a7eb-a3d5a0a0ade4', 'api')
# ('wsgi', '94354d4a-8c6c-4ecf-b97e-da2b349c22dd', 'api')
# ('wsgi', '20f425cc-c474-42dd-8d83-16b1e8c86466', 'api')
# ('wsgi', 'cf9286dd-6c2e-47ea-ac87-22ed41cc2aec', 'api')
# ('wsgi', '46fdccbe-e5cc-4f35-b995-c86fadf5c547', 'neutron-server')
# ('wsgi', 'a407b837-c327-482f-b476-69cd39547f75', 'neutron-server')
# ('wsgi', 'c5af3afe-61f2-421d-a985-54cb141543f2', 'neutron-server')
# ('db', 'f6af8762-827d-43b6-a495-71197c22cc39', 'api')
# ('wsgi', 'd26bede5-2672-458c-bdb3-49d52d6e77d3', 'neutron-server')
# ('wsgi', 'f5b1a392-7298-4f52-b565-f5f20238d24c', 'neutron-server')
# ('wsgi', 'fd4c9ae1-e862-4635-91bb-8f5232823547', 'api')
# ('wsgi', 'd54d6263-0900-40ac-982c-bb1640199bcb', 'api')
# ('db', '3ee04bee-934b-42aa-8b08-49151d62d494', 'api')
# ('wsgi', '30b1585a-49fa-4ada-8357-83378eea75a9', 'api')
# ('wsgi', '132c9db3-6e72-4940-86ab-dfd88af9099d', 'api')
# ('wsgi', 'd3db5bf4-b52d-412f-a0f9-be4b1ab85bfd', 'api')
# ('wsgi', '29ca9a63-f70c-4cab-ad37-e0aa323bc029', 'api')
# ('wsgi', 'f48956ac-3167-41bf-a0cc-f4b50139ac9b', 'api')
# ('wsgi', '810755fc-6773-4f89-930a-9d1631e12017', 'api')
# ('wsgi', 'fd18689a-6854-440f-9d48-ec97b8af6966', 'api')
# ('wsgi', 'd1ced1ef-609d-4cc4-8a43-7a6c54184966', 'api')
# ('wsgi', '15d74bc9-ca67-4f8e-a00b-9c2ffe8d7395', 'api')
# ('wsgi', '34cd00a3-ce6c-442e-8ea9-209827f53070', 'api')
# ('wsgi', '484d85db-04a5-4056-a407-ce26d4d8e5da', 'api')
# ('wsgi', '86a19645-c259-4519-aa2f-dbc9c6f947ef', 'api')
# ('db', '6c52c25a-a79e-4bce-809e-893ae822e736', 'api')
# ('wsgi', '78c9cedd-340f-45a3-beab-429b01577fa2', 'api')
# ('wsgi', 'e8cbc726-7ec5-469e-9f61-5ac58971c478', 'api')
# ('wsgi', 'bc23018b-5cab-4582-a5d3-f3af8b163e7c', 'api')
# ('wsgi', '7d085cec-bad5-4185-b715-11fa157d51b9', 'api')
# ('wsgi', 'a78a4dff-a028-4fb6-a66a-de8b064ef91e', 'neutron-server')
# ('wsgi', '68a6aa5d-6983-4ea6-b5c7-1a6b180781c0', 'api')
# ('db', '36d666e2-9d29-44c9-b6ef-c1d3d741b856', 'api')
# ('wsgi', '8f6b1bfc-ad4c-4cc8-a76d-165db6df7ec8', 'api')
# ('wsgi', '346450a4-ce7f-417d-bb96-e074f0b2f956', 'api')
# ('wsgi', 'f1df47fc-d4f0-440b-b1b4-85336b40e809', 'api')
# ('wsgi', '5c861e43-6b16-4f96-95eb-10c497137ab4', 'api')
# ('neutron.db', '8bb31a0a-88f3-4d89-8704-b6b58a77efa1', 'neutron-server')
# ('wsgi', '283003c3-3bba-4351-a97c-82c0b6b6ddb1', 'api')
# ('wsgi', '2c45135f-d25d-4368-8a5e-0495bacdf8e2', 'api')
# ('wsgi', '34b13815-f287-4fc8-b839-b18dad6435bc', 'neutron-server')
# ('wsgi', '98bb70c1-c194-4b06-94c4-b8787c9bd5da', 'api')
# ('wsgi', 'c3c60a85-5fa2-46a6-b7e7-45cb31926f1b', 'api')
# ('wsgi', '3aa7f7c1-93f3-4271-8caf-8f25f7a2e069', 'api')
# ('wsgi', '019203da-5249-43ac-b688-c841f9c141c0', 'api')
# ('wsgi', 'e0a730bd-c210-4953-ae16-e8dfa0aebb4d', 'api')
# ('wsgi', '51b643b7-5f93-42c5-b7e2-afcd95770bb0', 'api')
# ('wsgi', 'cfc65b63-fcf0-475f-b088-62bebde5a1cb', 'neutron-server')
# ('wsgi', '52fe6516-9aa7-483e-8ce8-4afdc8071b91', 'api')
# ('wsgi', 'cc58099a-1a4e-4c83-9faa-8b4f84ff4478', 'neutron-server')

# %% [markdown]
# For an event with both payload fields (payload-start and payload-stop) there exist some redundant fields.
# We want to determine whether the fields have the same values.
# We are looking at the following fields: host, service and project

# %%
def are_redundant_fields_equal(event):
    info_host = event['info'].get('host')
    info_service = event['info'].get('service')
    info_project = event['info'].get('project')
    assert info_host != None
    assert info_service != None
    assert info_project != None
    
    payload_start_name = get_payload_start_name(event)
    payload_stop_name = get_payload_stop_name(event)
    
    return info_host == event['info'][payload_start_name]['info']['host'] == event['info'][payload_stop_name]['info']['host'] and info_service == event['info'][payload_start_name]['service'] == event['info'][payload_stop_name]['service'] and info_project == event['info'][payload_start_name]['project'] == event['info'][payload_stop_name]['project']

def collect_events_where_values_in_redudant_fields_differ(event):
    if is_event_empty_or_top_level(event) or does_event_contain_both_payload_fields(event) == False: return [None] 
    if are_redundant_fields_equal(event):
        return [None]
    else:
        return [(name, event['trace_id'], event['info'].get('service'), info_host, payload_start_host, payload_stop_host)]
    
print_information(find_attribute_values(collect_events_where_values_in_redudant_fields_differ, True), 'Events where values in redundant fields differ', print_counts=False)
# Out:
# Events where values in redundant fields differ
# A total of 0 values were collected

# %% [markdown]
# We want to better understand the payload field. It contains different fields based on what kind of service is executed. So lets try to find out what kind of fields exist for each service.

# %%
# This function collects the keys of a dictionary recursively as a string representation
def collect_keys_recursively(payload_dict, earlier_keys = ''):
    if len(payload_dict) == 0: return earlier_keys
        
    for k,v in payload_dict.items():
        if len(earlier_keys) and earlier_keys[-1] != '-' and earlier_keys[-1] != '[':
            earlier_keys += '-'
        earlier_keys += str(k)
        if type(v) is dict:
            earlier_keys += '['
            earlier_keys = collect_keys_recursively(v, earlier_keys)
            earlier_keys += ']'
        
    return earlier_keys


def collect_keys_of_payload_fields(event):
    if is_event_empty_or_top_level(event) or does_event_contain_both_payload_fields(event) == False : 
        return [None]
    
    payload_start = event['info'][get_payload_start_name(event)]
    payload_stop = event['info'][get_payload_stop_name(event)]
    
    return [
        (
            event['info'].get('name'), 
            event['info'].get('service'),
            event['info'].get('project'),
            event['info'].get('host'),
            get_payload_start_name(event), 
            get_payload_stop_name(event), 
            collect_keys_recursively(payload_start), 
            collect_keys_recursively(payload_stop)
        )
    ]

event_attributes = find_attribute_values(collect_keys_of_payload_fields)
print_information(event_attributes)
# Out:
# Information about the values in the list:
# A total of 2519623 values were collected
# A total of 324 unique values were collected
# 547799 times: ('neutron_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 181562 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[target_tenant_1-target_tenant_2-target_tenant_3-target_tenant_4-id_1-action_2-action_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 167032 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 125539 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 125066 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 93155 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 81915 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[is_dynamic_1-network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 80585 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 79291 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 65598 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 55156 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 54475 times: ('wsgi', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 48089 times: ('wsgi', 'public', 'keystone', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 39529 times: ('rpc', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 39109 times: ('compute_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.compute_api-start', 'meta.raw_payload.compute_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 37732 times: ('wsgi', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 36312 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1-user_id_1-issued_before_1-audit_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 33257 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-project_id_2-device_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 32008 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 27556 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[network_id_1-is_dynamic_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 27547 times: ('wsgi', 'api', 'glance', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 24763 times: ('rpc', 'nova-scheduler', 'nova', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 18579 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-project_id_2-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 18579 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[id_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 18564 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 18561 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 13972 times: ('neutron_api', 'nova-compute', 'nova', 'wally122', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 12384 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-id_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 12382 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[allocated-vxlan_vni_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 12381 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[standardattributes_id-updated_at-standardattributes_revision_number]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 12378 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[device_owner_1-network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 12372 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[id-revision_number]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 9876 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted-deleted_at-updated_at-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 9856 times: ('neutron_api', 'nova-compute', 'nova', 'wally117', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 9237 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[created_at-updated_at-resource_type-description]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 8812 times: ('neutron_api', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 8664 times: ('neutron_api', 'nova-compute', 'nova', 'wally123', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 7672 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-project_id_2]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 7339 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[param_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6644 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[id_1-status_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6221 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-resource_1-param_1-project_id_2]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6195 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[status-availability_zone_hints-name-admin_state_up-mtu-vlan_transparent-standard_attr_id-project_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6195 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[segment_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6195 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[networks_id-mtu]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6195 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[network_id-port_security_enabled]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6195 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[availability_zone_hints-networks_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6195 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[param_1-network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6189 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-floating_network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6185 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[network_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6180 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-project_id_2-param_1-resource_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6143 times: ('rpc', 'neutron-dhcp-agent', 'neutron', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 5833 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[instance_actions_id-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 5769 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted_at-deleted_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 5762 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted_at-instance_uuid_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4829 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id-id-expiration]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4826 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[standardattributes_id-standardattributes_revision_number-revision_number-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4540 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[reservation_id-resource]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4504 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[domain_id_1-name_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4391 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[id_1-param_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4357 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4251 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[standardattributes_id-updated_at-revision_number-standardattributes_revision_number]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3424 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[instance_uuid-deleted-created_at-updated_at-value-key-deleted_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3390 times: ('neutron_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3363 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[reservation_id-amount-resource]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3351 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3312 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-deleted-created_at-updated_at-value-image_id-meta_data-deleted_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3304 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[standardattributes_id-revision_number-standardattributes_revision_number-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3300 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[instance_uuid_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3297 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[id_1-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3293 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-id_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3292 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted-deleted_at-updated_at-images_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3183 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[created_at-description-resource_type-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3146 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[name-network_id-segmentation_id-id-is_dynamic-physical_network-segment_index-standard_attr_id-network_type]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3049 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[name-network_id-segmentation_id-network_type-is_dynamic-physical_network-segment_index-standard_attr_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3032 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-target_tenant_2-action_1-network_id_1-target_tenant_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2957 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-deleted-deleted_at-image_locations_id-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2950 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2950 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[class_name_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2948 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[target_tenant_1-target_tenant_2-target_tenant_3-target_tenant_4-target_tenant_5-target_tenant_6-action_3-action_2-action_1-project_id_1-project_id_2]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2948 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[target_tenant_1-target_tenant_2-target_tenant_3-target_tenant_4-target_tenant_5-target_tenant_6-action_3-action_2-action_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2914 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[event_1-param_1-action_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2882 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_at-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2834 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[resource-amount-reservation_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2828 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[instance_uuid_1-param_1-request_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2779 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_7-deleted_6-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-param_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2636 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[finish_time-result-updated_at-instance_actions_events_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2548 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted_1-updated_at-instance_uuid_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2478 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[member_1-owner_1-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2142 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_7-deleted_6-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_3-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2130 times: ('nova_image', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.nova_image-start', 'meta.raw_payload.nova_image-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1981 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1972 times: ('rpc', 'nova-compute', 'nova', 'wally122', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1947 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[stats-vcpus_used-local_gb_used-updated_at-numa_topology-running_vms-free_disk_gb-compute_nodes_id-free_ram_mb-memory_mb_used]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1924 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[prior_role_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1894 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted_1-pci_requests-instance_uuid_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1803 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-task_state_1-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1777 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_6-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-param_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1667 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_7-deleted_3-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1652 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[resource-reservation_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1586 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1585 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-target_tenant_2-network_id_1-action_1-target_tenant_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1572 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[target_tenant_1-target_tenant_2-action_1-network_id_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1555 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[param_1-instance_uuid_1-deleted_1-request_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1539 times: ('compute_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.compute_api-start', 'meta.raw_payload.compute_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1507 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_7-param_1-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1478 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[host_1-key_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1476 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1476 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-root_device_name-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1475 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id_1-project_id_2-project_id_3]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1475 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[host_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1475 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1475 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1475 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1-user_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1475 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1-user_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1475 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[cell_id-updated_at-instance_mappings_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1473 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[id_1-updated_at-deleted_1-device_name]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1473 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_6-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_3-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1470 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[pci_requests-vcpu_model-device_metadata-updated_at-deleted_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1450 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[param_1-deleted_1-instance_uuid_1-request_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1444 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1-uuid_1-updated_at-deleted_1-cleaned]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1441 times: ('rpc', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1441 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[vm_state-uuid_1-terminated_at-updated_at-deleted_1-power_state-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1441 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[resource_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1378 times: ('rpc', 'nova-compute', 'nova', 'wally117', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1368 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id-expiration-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1303 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[type_1-actor_id_1-target_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1252 times: ('rpc', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1228 times: ('rpc', 'nova-compute', 'nova', 'wally123', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1217 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[target_id_1-actor_id_1-type_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1149 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-project_id_1-task_state_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1119 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1119 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[start_time-deleted-created_at-traceback-updated_at-finish_time-host-result-action_id-deleted_at-event-details]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1103 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[param_1-instance_uuid_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1097 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[instance_uuid_1-status_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1087 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_3-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 971 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[stats-vcpus_used-local_gb_used-updated_at-numa_topology-current_workload-running_vms-free_disk_gb-compute_nodes_id-free_ram_mb-memory_mb_used]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 968 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-param_1-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 966 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[deleted_1-flavor-updated_at-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 877 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[start_time-finish_time-created_at-traceback-updated_at-deleted-host-result-details-deleted_at-event-action_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 855 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-root_device_name-power_state-task_state_1-project_id_1-task_state-launched_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 840 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[user_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 830 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[owner_1-member_1-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 821 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[instance_uuid_1-updated_at-deleted_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 811 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[uuid_1-deleted_3-deleted_4-param_1-deleted_2-deleted_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 772 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[node-uuid_1-launched_on-deleted_1-updated_at-host-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# ...
# 24 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-checksum-owner-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 24 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-checksum-min_disk-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 24 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-name-id_1-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-os_hash_value-container_format-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 23 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 23 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 22 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 22 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-name-id_1-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-protected-os_hash_value-checksum-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 22 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-name-id_1-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-protected-os_hash_value-checksum-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 21 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-checksum-min_disk-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 21 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-checksum-owner-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 21 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 20 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 19 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 18 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 18 times: ('nova_image', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.nova_image-start', 'meta.raw_payload.nova_image-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 16 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[remote_group_id-direction-protocol-ethertype-port_range_max-security_group_id-port_range_min-remote_ip_prefix-standard_attr_id-project_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 16 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 16 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 12 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 11 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 10 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 10 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 10 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 10 times: ('neutron_api', 'nova-compute', 'nova', 'wally123', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 9 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 8 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[remote_group_id-direction-protocol-remote_ip_prefix-port_range_max-security_group_id-port_range_min-ethertype-standard_attr_id-project_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 8 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[project_id-security_group_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[id_1-revision_number_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 5 times: ('neutron_api', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4 times: ('nova_image', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.nova_image-start', 'meta.raw_payload.nova_image-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[standard_attr_id-project_id-id-name]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params[standard_attr_id-project_id-name-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[node-uuid_1-updated_at-deleted_1-host-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1-uuid_1-updated_at-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[node-uuid_1-availability_zone-updated_at-deleted_1-host-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[project_id_1-uuid_1-updated_at-deleted_1-availability_zone]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[finish_time-updated_at-instance_actions_events_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-checksum-os_hash_value-container_format-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')

# %%
print_information(list(map(lambda x : x[6], event_attributes)), 'Different payload-start features')
# Out:
# Different payload-start features
# A total of 2519623 values were collected
# A total of 290 unique values were collected
# 713014 times: info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id
# 351168 times: info[host-db[params[]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 223553 times: info[host-db[params[param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 222188 times: info[host-db[params[id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 181562 times: info[host-db[params[target_tenant_1-target_tenant_2-target_tenant_3-target_tenant_4-id_1-action_2-action_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 167843 times: info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 81915 times: info[host-db[params[is_dynamic_1-network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 36312 times: info[host-db[params[project_id_1-user_id_1-issued_before_1-audit_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 33257 times: info[host-db[params[project_id_1-project_id_2-device_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 32008 times: info[host-db[params[image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 27556 times: info[host-db[params[network_id_1-is_dynamic_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 19070 times: info[host-db[params[id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 18579 times: info[host-db[params[project_id_1-project_id_2-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 18579 times: info[host-db[params[id_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 18561 times: info[host-db[params[network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 12384 times: info[host-db[params[project_id_1-id_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 12382 times: info[host-db[params[allocated-vxlan_vni_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 12381 times: info[host-db[params[standardattributes_id-updated_at-standardattributes_revision_number]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 12378 times: info[host-db[params[device_owner_1-network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 12372 times: info[host-db[params[id-revision_number]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 9876 times: info[host-db[params[deleted-deleted_at-updated_at-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 9237 times: info[host-db[params[created_at-updated_at-resource_type-description]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 7672 times: info[host-db[params[project_id_1-project_id_2]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 7339 times: info[host-db[params[param_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6644 times: info[host-db[params[id_1-status_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6221 times: info[host-db[params[project_id_1-resource_1-param_1-project_id_2]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6195 times: info[host-db[params[status-availability_zone_hints-name-admin_state_up-mtu-vlan_transparent-standard_attr_id-project_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6195 times: info[host-db[params[segment_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6195 times: info[host-db[params[networks_id-mtu]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6195 times: info[host-db[params[network_id-port_security_enabled]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6195 times: info[host-db[params[availability_zone_hints-networks_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6195 times: info[host-db[params[param_1-network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6189 times: info[host-db[params[project_id_1-floating_network_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6185 times: info[host-db[params[network_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6180 times: info[host-db[params[project_id_1-project_id_2-param_1-resource_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 5833 times: info[host-db[params[instance_actions_id-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 5769 times: info[host-db[params[deleted_at-deleted_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 5762 times: info[host-db[params[deleted_at-instance_uuid_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4829 times: info[host-db[params[project_id-id-expiration]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4826 times: info[host-db[params[standardattributes_id-standardattributes_revision_number-revision_number-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4540 times: info[host-db[params[reservation_id-resource]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4536 times: info[host-db[params[project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4504 times: info[host-db[params[domain_id_1-name_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4391 times: info[host-db[params[id_1-param_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4357 times: info[host-db[params[instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4251 times: info[host-db[params[standardattributes_id-updated_at-revision_number-standardattributes_revision_number]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3424 times: info[host-db[params[instance_uuid-deleted-created_at-updated_at-value-key-deleted_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3363 times: info[host-db[params[reservation_id-amount-resource]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3312 times: info[host-db[params[status-deleted-created_at-updated_at-value-image_id-meta_data-deleted_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3304 times: info[host-db[params[standardattributes_id-revision_number-standardattributes_revision_number-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3300 times: info[host-db[params[instance_uuid_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3297 times: info[host-db[params[id_1-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3293 times: info[host-db[params[status-id_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3292 times: info[host-db[params[deleted-deleted_at-updated_at-images_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3183 times: info[host-db[params[created_at-description-resource_type-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3146 times: info[host-db[params[name-network_id-segmentation_id-id-is_dynamic-physical_network-segment_index-standard_attr_id-network_type]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3049 times: info[host-db[params[name-network_id-segmentation_id-network_type-is_dynamic-physical_network-segment_index-standard_attr_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3032 times: info[host-db[params[project_id_1-target_tenant_2-action_1-network_id_1-target_tenant_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2957 times: info[host-db[params[status-deleted-deleted_at-image_locations_id-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2950 times: info[host-db[params[class_name_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2948 times: info[host-db[params[target_tenant_1-target_tenant_2-target_tenant_3-target_tenant_4-target_tenant_5-target_tenant_6-action_3-action_2-action_1-project_id_1-project_id_2]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2948 times: info[host-db[params[target_tenant_1-target_tenant_2-target_tenant_3-target_tenant_4-target_tenant_5-target_tenant_6-action_3-action_2-action_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2914 times: info[host-db[params[event_1-param_1-action_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2882 times: info[host-db[params[uuid_1-deleted_at-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2834 times: info[host-db[params[resource-amount-reservation_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2828 times: info[host-db[params[instance_uuid_1-param_1-request_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2779 times: info[host-db[params[uuid_1-deleted_7-deleted_6-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-param_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2636 times: info[host-db[params[finish_time-result-updated_at-instance_actions_events_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2548 times: info[host-db[params[deleted_1-updated_at-instance_uuid_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2478 times: info[host-db[params[member_1-owner_1-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2142 times: info[host-db[params[uuid_1-deleted_7-deleted_6-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_3-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1947 times: info[host-db[params[stats-vcpus_used-local_gb_used-updated_at-numa_topology-running_vms-free_disk_gb-compute_nodes_id-free_ram_mb-memory_mb_used]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1924 times: info[host-db[params[prior_role_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1894 times: info[host-db[params[deleted_1-pci_requests-instance_uuid_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1803 times: info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-task_state_1-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1777 times: info[host-db[params[uuid_1-deleted_6-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-param_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1667 times: info[host-db[params[uuid_1-deleted_7-deleted_3-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1652 times: info[host-db[params[resource-reservation_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1630 times: info[host-db[params[host_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1585 times: info[host-db[params[project_id_1-target_tenant_2-network_id_1-action_1-target_tenant_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1572 times: info[host-db[params[target_tenant_1-target_tenant_2-action_1-network_id_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1555 times: info[host-db[params[param_1-instance_uuid_1-deleted_1-request_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1507 times: info[host-db[params[uuid_1-deleted_7-param_1-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1478 times: info[host-db[params[host_1-key_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1476 times: info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1476 times: info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-root_device_name-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1475 times: info[host-db[params[project_id_1-project_id_2-project_id_3]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1475 times: info[host-db[params[uuid_1-param_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1475 times: info[host-db[params[project_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1475 times: info[host-db[params[project_id_1-user_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1475 times: info[host-db[params[project_id_1-user_id_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1475 times: info[host-db[params[cell_id-updated_at-instance_mappings_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1473 times: info[host-db[params[id_1-updated_at-deleted_1-device_name]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1473 times: info[host-db[params[uuid_1-deleted_6-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_3-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1470 times: info[host-db[params[pci_requests-vcpu_model-device_metadata-updated_at-deleted_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1450 times: info[host-db[params[param_1-deleted_1-instance_uuid_1-request_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1444 times: info[host-db[params[project_id_1-uuid_1-updated_at-deleted_1-cleaned]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1441 times: info[host-db[params[vm_state-uuid_1-terminated_at-updated_at-deleted_1-power_state-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1441 times: info[host-db[params[resource_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1368 times: info[host-db[params[project_id-expiration-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1303 times: info[host-db[params[type_1-actor_id_1-target_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1217 times: info[host-db[params[target_id_1-actor_id_1-type_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1149 times: info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-project_id_1-task_state_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1119 times: info[host-db[params[deleted_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1119 times: info[host-db[params[start_time-deleted-created_at-traceback-updated_at-finish_time-host-result-action_id-deleted_at-event-details]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1103 times: info[host-db[params[param_1-instance_uuid_1-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1097 times: info[host-db[params[instance_uuid_1-status_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 1087 times: info[host-db[params[uuid_1-deleted_3-deleted_5-deleted_4-param_1-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 971 times: info[host-db[params[stats-vcpus_used-local_gb_used-updated_at-numa_topology-current_workload-running_vms-free_disk_gb-compute_nodes_id-free_ram_mb-memory_mb_used]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 968 times: info[host-db[params[uuid_1-param_1-deleted_5-deleted_4-deleted_3-deleted_2-deleted_1-deleted_6-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 966 times: info[host-db[params[deleted_1-flavor-updated_at-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 877 times: info[host-db[params[start_time-finish_time-created_at-traceback-updated_at-deleted-host-result-details-deleted_at-event-action_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 855 times: info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-root_device_name-power_state-task_state_1-project_id_1-task_state-launched_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 840 times: info[host-db[params[user_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 830 times: info[host-db[params[owner_1-member_1-image_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 821 times: info[host-db[params[instance_uuid_1-updated_at-deleted_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 811 times: info[host-db[params[uuid_1-deleted_3-deleted_4-param_1-deleted_2-deleted_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 772 times: info[host-db[params[node-uuid_1-launched_on-deleted_1-updated_at-host-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 770 times: info[host-db[params[uuid_1-deleted_7-deleted_6-deleted_5-deleted_4-param_1-deleted_3-deleted_1-deleted_2-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 704 times: info[host-db[params[node-uuid_1-updated_at-deleted_1-launched_on-host-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 656 times: info[host-db[params[instance_uuid_1-pci_requests-deleted_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 630 times: info[host-db[params[uuid_1-param_1-deleted_4-deleted_3-deleted_2-deleted_1-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 615 times: info[host-db[params[vm_state-uuid_1-updated_at-deleted_1-root_device_name-power_state-project_id_1-task_state_1-task_state-launched_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 488 times: info[host-db[params[uuid_1-deleted_6-deleted_5-deleted_4-param_1-deleted_3-deleted_1-deleted_2-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 376 times: info[host-db[params[param_1-deleted_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 373 times: info[host-db[params[status_1-instance_uuid_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 343 times: info[host-db[params[status-name-checksum-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-container_format-owner-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 342 times: info[host-db[params[deleted_1-numa_topology-pci_requests-instance_uuid_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 340 times: info[host-db[params[deleted-status-deleted_at-image_locations_id-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 330 times: info[host-db[params[status-name-checksum-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-container_format-min_disk-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 326 times: info[host-db[params[status-name-checksum-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-container_format-owner-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 322 times: info[host-db[params[numa_topology-instance_uuid_1-pci_requests-deleted_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 314 times: info[host-db[params[created_at-deleted-start_time-traceback-updated_at-finish_time-host-result-details-deleted_at-event-action_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 312 times: info[host-db[params[status-name-checksum-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 307 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-checksum-min_disk-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 305 times: info[host-db[params[finish_time-start_time-traceback-updated_at-event-deleted-host-result-details-deleted_at-created_at-action_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 304 times: info[host-db[params[start_time-deleted-created_at-traceback-updated_at-finish_time-host-result-details-deleted_at-event-action_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 293 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-checksum-owner-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 292 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-checksum-owner-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 282 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-checksum-min_disk-protected-virtual_size-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 275 times: info[host-db[params[finish_time-instance_actions_events_id-result-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 263 times: info[host-db[params[status-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-os_hidden-id_1-os_hash_value-checksum-min_disk-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 249 times: info[host-db[params[status-name-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-os_hidden-id_1-os_hash_value-container_format-min_disk-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 224 times: info[host-db[params[status-name-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-os_hidden-id_1-os_hash_value-container_format-min_disk-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 206 times: info[host-db[params[updated_at-deleted_1-instance_uuid_1-numa_topology-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 204 times: info[host-db[params[status-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-os_hidden-id_1-os_hash_value-checksum-min_disk-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 198 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-os_hash_algo-visibility-updated_at-os_hidden-protected-id-os_hash_value-container_format-min_disk-owner-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 194 times: info[host-db[params[status-deleted_at-name-deleted-disk_format-created_at-os_hidden-updated_at-visibility-os_hash_algo-min_disk-protected-min_ram-checksum-os_hash_value-container_format-owner-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 188 times: info[host-db[params[flavor-instance_uuid_1-updated_at-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 186 times: info[host-db[params[deleted_1-numa_topology-updated_at-instance_uuid_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 183 times: info[host-db[params[numa_topology-instance_uuid_1-updated_at-deleted_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 167 times: info[host-db[params[updated_at-instance_uuid_1-numa_topology-deleted_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 165 times: info[host-db[params[flavor-instance_uuid_1-deleted_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 143 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-updated_at-visibility-os_hash_algo-min_disk-protected-min_ram-os_hash_value-checksum-owner-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 142 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-updated_at-visibility-os_hash_algo-min_disk-protected-min_ram-os_hash_value-container_format-owner-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 141 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-min_ram-os_hash_value-container_format-min_disk-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 122 times: info[host-db[params[flavor-deleted_1-instance_uuid_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 117 times: info[host-db[params[status-deleted_at-name-deleted-disk_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-min_disk-protected-min_ram-checksum-os_hash_value-container_format-owner-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 116 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-updated_at-visibility-os_hash_algo-os_hidden-protected-min_ram-os_hash_value-checksum-min_disk-owner-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 108 times: info[host-db[params[status-deleted_at-name-deleted-disk_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-min_ram-checksum-os_hash_value-container_format-min_disk-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 105 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-min_ram-os_hash_value-checksum-owner-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 103 times: info[host-db[params[status-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-id_1-os_hash_value-checksum-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 102 times: info[host-db[params[status-name-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-id_1-os_hash_value-container_format-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 98 times: info[host-db[params[status-name-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-protected-id_1-os_hash_value-container_format-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 97 times: info[host-db[params[status-name-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-protected-id_1-os_hash_value-container_format-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 95 times: info[host-db[params[status-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-protected-id_1-os_hash_value-checksum-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 92 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-checksum-os_hash_value-container_format-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 91 times: info[host-db[params[status-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-protected-id_1-os_hash_value-checksum-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 88 times: info[host-db[params[status-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-protected-id_1-os_hash_value-checksum-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 88 times: info[host-db[params[status-deleted_at-name-deleted-checksum-created_at-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-id-os_hash_value-container_format-min_disk-virtual_size-disk_format-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 87 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-os_hidden-updated_at-visibility-os_hash_algo-min_disk-protected-min_ram-os_hash_value-container_format-owner-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 87 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-checksum-owner-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 86 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-updated_at-visibility-os_hash_algo-owner-protected-min_ram-os_hash_value-container_format-min_disk-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 85 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-min_ram-os_hash_value-checksum-min_disk-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 84 times: info[host-db[params[status-deleted_at-name-deleted-container_format-created_at-disk_format-updated_at-visibility-os_hash_algo-os_hidden-protected-min_ram-os_hash_value-checksum-min_disk-owner-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 82 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-id_1-checksum-os_hash_value-container_format-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 82 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-id-os_hash_value-checksum-owner-os_hidden-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 80 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-checksum-min_disk-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 80 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-checksum-os_hash_value-container_format-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 79 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-min_disk-protected-min_ram-os_hash_value-checksum-owner-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 77 times: info[host-db[params[status-virtual_size-name-deleted-disk_format-created_at-os_hidden-updated_at-visibility-os_hash_algo-owner-protected-min_ram-checksum-os_hash_value-container_format-min_disk-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 76 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-checksum-min_disk-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 76 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-checksum-owner-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 75 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-checksum-os_hash_value-container_format-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 75 times: info[host-db[params[status-name-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-protected-id_1-os_hash_value-container_format-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 72 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-os_hidden-id_1-os_hash_value-container_format-min_disk-protected-owner-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 70 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-os_hidden-id_1-os_hash_value-checksum-min_disk-protected-owner-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 70 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-container_format-owner-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 67 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-id_1-checksum-os_hash_value-container_format-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 65 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-checksum-os_hash_value-container_format-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 60 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-os_hidden-id_1-os_hash_value-container_format-min_disk-protected-owner-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 60 times: info[host-db[params[status-virtual_size-name-deleted-disk_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-id-checksum-os_hash_value-container_format-min_disk-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 59 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-id_1-checksum-os_hash_value-container_format-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 55 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-checksum-os_hash_value-container_format-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 55 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-container_format-owner-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 54 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-os_hidden-id_1-os_hash_value-checksum-min_disk-protected-owner-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 53 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-os_hash_algo-visibility-updated_at-os_hidden-protected-min_ram-os_hash_value-checksum-min_disk-owner-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 51 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-min_disk-protected-id-os_hash_value-checksum-owner-deleted_at-disk_format-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 50 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 50 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-container_format-min_disk-protected-disk_format-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 49 times: info[host-db[params[status-virtual_size-name-deleted-os_hidden-created_at-disk_format-os_hash_algo-visibility-updated_at-container_format-min_disk-protected-id-os_hash_value-checksum-owner-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 49 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-checksum-os_hash_value-disk_format-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 48 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-updated_at-visibility-os_hash_algo-os_hidden-protected-id-os_hash_value-container_format-min_disk-owner-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 47 times: info[host-db[params[status-deleted_at-name-deleted-disk_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-id-checksum-os_hash_value-container_format-min_disk-virtual_size-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 47 times: info[host-db[params[status-name-id_1-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-protected-os_hash_value-checksum-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 45 times: info[host-db[params[status-created_at-deleted_at-name-deleted-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-protected-os_hash_value-checksum-owner-os_hidden-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 44 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-checksum-os_hash_value-disk_format-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 44 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-os_hidden-updated_at-visibility-os_hash_algo-min_disk-protected-id-os_hash_value-checksum-owner-deleted_at-disk_format-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 43 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-id-os_hash_value-container_format-owner-os_hidden-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 43 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 43 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-updated_at-visibility-os_hash_algo-owner-protected-id-os_hash_value-container_format-min_disk-os_hidden-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 43 times: info[host-db[params[status-virtual_size-name-deleted-disk_format-created_at-os_hidden-os_hash_algo-visibility-updated_at-container_format-min_disk-protected-min_ram-os_hash_value-checksum-owner-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 43 times: info[host-db[params[status-virtual_size-name-deleted-os_hidden-created_at-disk_format-updated_at-visibility-os_hash_algo-container_format-min_disk-protected-id-os_hash_value-checksum-owner-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 43 times: info[host-db[params[status-deleted_at-name-deleted-checksum-created_at-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-min_ram-os_hash_value-container_format-min_disk-virtual_size-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 42 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-os_hidden-updated_at-visibility-os_hash_algo-owner-protected-id-os_hash_value-checksum-min_disk-deleted_at-disk_format-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 42 times: info[host-db[params[status-deleted_at-name-deleted-container_format-created_at-disk_format-os_hash_algo-visibility-updated_at-os_hidden-protected-min_ram-os_hash_value-checksum-min_disk-owner-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 42 times: info[host-db[params[status-created_at-virtual_size-name-deleted-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-os_hash_value-container_format-owner-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 41 times: info[host-db[params[status-deleted_at-name-deleted-checksum-created_at-disk_format-updated_at-visibility-os_hash_algo-os_hidden-protected-id-os_hash_value-container_format-min_disk-owner-virtual_size-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 41 times: info[host-db[params[status-deleted_at-name-deleted-os_hidden-created_at-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-min_ram-checksum-os_hash_value-container_format-owner-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 40 times: info[host-db[params[status-deleted_at-name-deleted-os_hidden-created_at-disk_format-updated_at-visibility-os_hash_algo-container_format-min_disk-protected-min_ram-os_hash_value-checksum-owner-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 40 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-updated_at-visibility-os_hash_algo-owner-protected-id-os_hash_value-checksum-min_disk-os_hidden-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 40 times: info[host-db[params[status-created_at-deleted_at-name-deleted-checksum-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-os_hash_value-container_format-min_disk-virtual_size-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 40 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-os_hidden-updated_at-visibility-os_hash_algo-owner-protected-min_ram-os_hash_value-container_format-min_disk-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 39 times: info[host-db[params[status-created_at-virtual_size-name-deleted-checksum-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-protected-os_hash_value-container_format-min_disk-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 38 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-checksum-os_hash_value-disk_format-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 37 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-os_hash_algo-visibility-updated_at-owner-protected-min_ram-os_hash_value-container_format-min_disk-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 36 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 36 times: info[host-db[params[status-virtual_size-name-deleted-os_hidden-created_at-disk_format-updated_at-visibility-os_hash_algo-owner-protected-id-checksum-os_hash_value-container_format-min_disk-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 36 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-min_ram-os_hash_value-container_format-owner-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 36 times: info[host-db[params[status-virtual_size-name-deleted-os_hidden-created_at-disk_format-os_hash_algo-visibility-updated_at-container_format-owner-protected-min_ram-os_hash_value-checksum-min_disk-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 35 times: info[host-db[params[numa_topology-pci_requests-instance_uuid_1-deleted_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 35 times: info[host-db[params[updated_at-numa_topology-instance_uuid_1-deleted_1-pci_requests]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 35 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 35 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-os_hash_algo-visibility-updated_at-os_hidden-protected-id-os_hash_value-checksum-min_disk-owner-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 35 times: info[host-db[params[status-deleted_at-name-deleted-os_hidden-created_at-disk_format-updated_at-visibility-os_hash_algo-container_format-owner-protected-min_ram-os_hash_value-checksum-min_disk-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 35 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-os_hash_algo-visibility-updated_at-owner-protected-id-os_hash_value-container_format-min_disk-os_hidden-deleted_at-min_ram-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 34 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 33 times: info[host-db[params[status-name-container_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-checksum-os_hash_value-disk_format-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 33 times: info[host-db[params[status-name-id_1-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-os_hash_value-checksum-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 32 times: info[host-db[params[status-deleted_at-name-deleted-checksum-created_at-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-min_ram-os_hash_value-container_format-owner-os_hidden-virtual_size-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 32 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-disk_format-updated_at-visibility-os_hash_algo-owner-protected-min_ram-os_hash_value-checksum-min_disk-os_hidden-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 31 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-os_hidden-os_hash_algo-visibility-updated_at-min_disk-protected-min_ram-os_hash_value-container_format-owner-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 30 times: info[host-db[params[status-name-id_1-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-protected-os_hash_value-container_format-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 30 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 30 times: info[host-db[params[status-virtual_size-name-deleted-checksum-created_at-disk_format-updated_at-visibility-os_hash_algo-os_hidden-protected-min_ram-os_hash_value-container_format-min_disk-owner-deleted_at-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 28 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 27 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 27 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-container_format-min_disk-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 27 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 26 times: info[host-db[params[status-name-id_1-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-protected-os_hash_value-container_format-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 26 times: info[host-db[params[status-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 25 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-container_format-owner-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 25 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-container_format-owner-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 25 times: info[host-db[params[status-virtual_size-name-deleted-container_format-created_at-os_hidden-updated_at-visibility-os_hash_algo-owner-protected-min_ram-os_hash_value-checksum-min_disk-deleted_at-disk_format-id-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 24 times: info[host-db[params[status-name-id_1-checksum-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-protected-os_hash_value-container_format-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 24 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-checksum-owner-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 24 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-checksum-min_disk-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 24 times: info[host-db[params[status-name-id_1-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-protected-os_hash_value-container_format-owner-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 23 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 23 times: info[host-db[params[status-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 22 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 22 times: info[host-db[params[status-name-id_1-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-protected-os_hash_value-checksum-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 22 times: info[host-db[params[status-name-id_1-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-protected-os_hash_value-checksum-min_disk-os_hidden-virtual_size-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 21 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-checksum-min_disk-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 21 times: info[host-db[params[status-virtual_size-name-container_format-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-checksum-owner-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 21 times: info[host-db[params[status-virtual_size-name-checksum-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-os_hidden-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 20 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 19 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 18 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-container_format-min_disk-id_1-os_hash_value-checksum-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 16 times: info[host-db[params[remote_group_id-direction-protocol-ethertype-port_range_max-security_group_id-port_range_min-remote_ip_prefix-standard_attr_id-project_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 16 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-container_format-owner-id_1-os_hash_value-checksum-min_disk-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 16 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 12 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 11 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 10 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 10 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 10 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-os_hash_algo-visibility-updated_at-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 9 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-owner-id_1-os_hash_value-container_format-min_disk-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 8 times: info[host-db[params[remote_group_id-direction-protocol-remote_ip_prefix-port_range_max-security_group_id-port_range_min-ethertype-standard_attr_id-project_id-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 8 times: info[host-db[params[status-virtual_size-name-disk_format-min_ram-os_hidden-updated_at-visibility-os_hash_algo-min_disk-id_1-os_hash_value-container_format-owner-protected-checksum-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6 times: info[host-db[params[project_id-security_group_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 6 times: info[host-db[params[id_1-revision_number_1-updated_at]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3 times: info[host-db[params[standard_attr_id-project_id-id-name]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3 times: info[host-db[params[standard_attr_id-project_id-name-id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3 times: info[host-db[params[node-uuid_1-updated_at-deleted_1-host-project_id_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3 times: info[host-db[params[project_id_1-uuid_1-updated_at-deleted_1]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3 times: info[host-db[params[node-uuid_1-availability_zone-updated_at-deleted_1-host-project_id_1-task_state]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3 times: info[host-db[params[project_id_1-uuid_1-updated_at-deleted_1-availability_zone]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 3 times: info[host-db[params[finish_time-updated_at-instance_actions_events_id]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 2 times: info[host-db[params[status-virtual_size-name-os_hidden-min_ram-disk_format-os_hash_algo-visibility-updated_at-min_disk-id_1-checksum-os_hash_value-container_format-owner-protected-id-status_1-size]-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id

# %% [markdown]
# In the earlier output we could see that the features mainly vary because the params field contain different keys.
# These are the params that get passed to a database query. Im going to adapt our collect function to not further descend into the dict if it is the 'params' field:

# %%
def collect_keys_recursively_exclude_params(payload_dict, earlier_keys = ''):
    if len(payload_dict) == 0: return earlier_keys
        
    for k,v in payload_dict.items():
        if len(earlier_keys) and earlier_keys[-1] != '-' and earlier_keys[-1] != '[':
            earlier_keys += '-'
        earlier_keys += str(k)
        if type(v) is dict and str(k) != 'params':
            earlier_keys += '['
            earlier_keys = collect_keys_recursively_exclude_params(v, earlier_keys)
            earlier_keys += ']'
        
    return earlier_keys

def collect_keys_of_payload_fields_exclude_param(event):
    if is_event_empty_or_top_level(event) or does_event_contain_both_payload_fields(event) == False : 
        return [None]
    
    payload_start = event['info'][get_payload_start_name(event)]
    payload_stop = event['info'][get_payload_stop_name(event)]
    
    return [
        (
            event['info'].get('name'), 
            event['info'].get('service'),
            event['info'].get('project'),
            event['info'].get('host'),
            get_payload_start_name(event), 
            get_payload_stop_name(event), 
            collect_keys_recursively_exclude_params(payload_start), 
            collect_keys_recursively_exclude_params(payload_stop)
        )
    ]

event_attributes_exclude_params_field = find_attribute_values(collect_keys_of_payload_fields_exclude_param)
print_information(event_attributes_exclude_params_field)
# Out:
# Information about the values in the list:
# A total of 2519623 values were collected
# A total of 30 unique values were collected
# 978997 times: ('neutron.db', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.neutron.db-start', 'meta.raw_payload.neutron.db-stop', 'info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 547799 times: ('neutron_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 238350 times: ('db', 'public', 'keystone', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 217414 times: ('db', 'api', 'glance', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 203695 times: ('db', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 54475 times: ('wsgi', 'neutron-server', 'neutron', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 48089 times: ('wsgi', 'public', 'keystone', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 39529 times: ('rpc', 'nova-conductor', 'nova', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 39109 times: ('compute_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.compute_api-start', 'meta.raw_payload.compute_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 37732 times: ('wsgi', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 27547 times: ('wsgi', 'api', 'glance', 'wally113', 'meta.raw_payload.wsgi-start', 'meta.raw_payload.wsgi-stop', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 24763 times: ('rpc', 'nova-scheduler', 'nova', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 13972 times: ('neutron_api', 'nova-compute', 'nova', 'wally122', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 9856 times: ('neutron_api', 'nova-compute', 'nova', 'wally117', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 8812 times: ('neutron_api', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 8664 times: ('neutron_api', 'nova-compute', 'nova', 'wally123', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 6143 times: ('rpc', 'neutron-dhcp-agent', 'neutron', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 3390 times: ('neutron_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2130 times: ('nova_image', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.nova_image-start', 'meta.raw_payload.nova_image-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1972 times: ('rpc', 'nova-compute', 'nova', 'wally122', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1539 times: ('compute_api', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.compute_api-start', 'meta.raw_payload.compute_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1441 times: ('rpc', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1378 times: ('rpc', 'nova-compute', 'nova', 'wally117', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1252 times: ('rpc', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 1228 times: ('rpc', 'nova-compute', 'nova', 'wally123', 'meta.raw_payload.rpc-start', 'meta.raw_payload.rpc-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 310 times: ('db', 'nova-scheduler', 'nova', 'wally113', 'meta.raw_payload.db-start', 'meta.raw_payload.db-stop', 'info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 18 times: ('nova_image', 'osapi_compute', 'nova', 'wally113', 'meta.raw_payload.nova_image-start', 'meta.raw_payload.nova_image-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 10 times: ('neutron_api', 'nova-compute', 'nova', 'wally123', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 5 times: ('neutron_api', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.neutron_api-start', 'meta.raw_payload.neutron_api-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4 times: ('nova_image', 'nova-compute', 'nova', 'wally124', 'meta.raw_payload.nova_image-start', 'meta.raw_payload.nova_image-stop', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')

# %%
print_information(list(map(lambda x: x[6], event_attributes_exclude_params_field)), 'Different payload-start features if we do not descend inside the params dict')
# Out:
# Different payload-start features if we do not descend inside the params dict
# A total of 2519623 values were collected
# A total of 3 unique values were collected
# 1638766 times: info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id
# 713014 times: info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id
# 167843 times: info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id

# %%
print_information(list(map(lambda x : x[7], event_attributes)), 'Different payload-stop features')
# Out:
# Different payload-stop features
# A total of 2519623 values were collected
# A total of 2 unique values were collected
# 2514661 times: info[host]-name-service-timestamp-trace_id-project-parent_id-base_id
# 4962 times: info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id

# %% [markdown]
# No params field here, so this will be the same for both collect-keys functions. The second feature appears when an exception occured

# %%
print_information(list(map(lambda x : (x[6], x[7]), event_attributes_exclude_params_field)), 'Different payload-start/ payload-stop feature combination')
# Out:
# Different payload-start/ payload-stop feature combination
# A total of 2519623 values were collected
# A total of 4 unique values were collected
# 1638766 times: ('info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 708052 times: ('info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 167843 times: ('info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 4962 times: ('info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id', 'info[etype-message-host]-name-service-timestamp-trace_id-project-parent_id-base_id')

# %%
print_information(list(map(lambda x: (x[0], x[6]), event_attributes_exclude_params_field)), 'Combination of name and payload-start features')
# Out:
# Combination of name and payload-start features
# A total of 2519623 values were collected
# A total of 7 unique values were collected
# 978997 times: ('neutron.db', 'info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 659769 times: ('db', 'info[host-db[params-statement]]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 592508 times: ('neutron_api', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 167843 times: ('wsgi', 'info[host-request[path-scheme-method-query]]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 77706 times: ('rpc', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 40648 times: ('compute_api', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id')
# 2152 times: ('nova_image', 'info[function[args-name-kwargs]-host]-name-service-timestamp-trace_id-project-parent_id-base_id')

# %% [markdown]
# We have 7 unique names and 7 unique combinations of name and payload-start features. **Therefore is the name field sufficient to infer what kind of features the payload-start field contains.**
# The exception can also be infered from the payload.
