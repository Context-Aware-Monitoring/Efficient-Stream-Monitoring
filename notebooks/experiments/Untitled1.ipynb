# %%
import pdb
import sys
sys.path.append("../../src")
from reward_information import RewardInformation

# %%
reward = RewardInformation('../../data/processed/seq_rewards_w30_s5_MI_n1.csv')
reward.get_top_rank_count_for_arms()
# Out:
# A total of 42 different arms atleast once receive the highest reward
# [('wally122.mem.used-wally124.mem.used', 4079),
#  ('wally117.mem.used-wally124.mem.used', 4070),
#  ('wally117.mem.used-wally122.mem.used', 3965),
#  ('wally123.mem.used-wally124.mem.used', 3810),
#  ('wally122.mem.used-wally123.mem.used', 3704),
#  ('wally117.mem.used-wally123.mem.used', 3701),
#  ('wally113.mem.used-wally124.mem.used', 3658),
#  ('wally113.mem.used-wally117.mem.used', 3577),
#  ('wally113.mem.used-wally122.mem.used', 3556),
#  ('wally113.mem.used-wally123.mem.used', 3313),
#  ('wally113.cpu.user-wally124.mem.used', 164),
#  ('wally113.cpu.user-wally122.mem.used', 161),
#  ('wally113.cpu.user-wally117.mem.used', 155),
#  ('wally113.cpu.user-wally113.mem.used', 148),
#  ('wally113.cpu.user-wally123.mem.used', 132),
#  ('wally122.cpu.user-wally122.mem.used', 102),
#  ('wally122.cpu.user-wally124.mem.used', 102),
#  ('wally117.mem.used-wally122.cpu.user', 96),
# ...

# %%
reward.get_top_L_rank_count_for_arms(5)
# Out:
# A total of 43 different arms atleast once receive a reward within the top-5
# [('wally122.mem.used-wally124.mem.used', 4327),
#  ('wally117.mem.used-wally124.mem.used', 4313),
#  ('wally117.mem.used-wally122.mem.used', 4222),
#  ('wally123.mem.used-wally124.mem.used', 4101),
#  ('wally117.mem.used-wally123.mem.used', 3966),
#  ('wally122.mem.used-wally123.mem.used', 3955),
#  ('wally113.mem.used-wally124.mem.used', 3947),
#  ('wally113.mem.used-wally122.mem.used', 3860),
#  ('wally113.mem.used-wally117.mem.used', 3796),
#  ('wally113.mem.used-wally123.mem.used', 3577),
#  ('wally113.cpu.user-wally124.mem.used', 180),
#  ('wally113.cpu.user-wally122.mem.used', 176),
#  ('wally113.cpu.user-wally117.mem.used', 171),
#  ('wally113.cpu.user-wally113.mem.used', 165),
#  ('wally113.cpu.user-wally123.mem.used', 139),
#  ('wally122.cpu.user-wally122.mem.used', 122),
#  ('wally122.cpu.user-wally124.mem.used', 120),
#  ('wally124.cpu.user-wally124.mem.used', 116),
# ...

# %%
reward.get_top_L_rank_count_for_arms(10)
# Out:
# A total of 45 different arms atleast once receive a reward within the top-10
# [('wally117.mem.used-wally124.mem.used', 4870),
#  ('wally122.mem.used-wally124.mem.used', 4867),
#  ('wally117.mem.used-wally122.mem.used', 4828),
#  ('wally123.mem.used-wally124.mem.used', 4809),
#  ('wally113.mem.used-wally124.mem.used', 4805),
#  ('wally122.mem.used-wally123.mem.used', 4776),
#  ('wally117.mem.used-wally123.mem.used', 4773),
#  ('wally113.mem.used-wally122.mem.used', 4767),
#  ('wally113.mem.used-wally117.mem.used', 4750),
#  ('wally113.mem.used-wally123.mem.used', 4693),
#  ('wally113.cpu.user-wally124.mem.used', 335),
#  ('wally113.cpu.user-wally122.mem.used', 312),
#  ('wally113.cpu.user-wally117.mem.used', 302),
#  ('wally113.cpu.user-wally113.mem.used', 286),
#  ('wally122.cpu.user-wally124.mem.used', 286),
#  ('wally122.cpu.user-wally122.mem.used', 274),
#  ('wally124.cpu.user-wally124.mem.used', 269),
#  ('wally117.cpu.user-wally124.mem.used', 261),
# ...

# %%
reward.get_top_L_rank_count_for_arms(20)
# Out:
# A total of 45 different arms atleast once receive a reward within the top-20
# [('wally117.mem.used-wally122.mem.used', 4931),
#  ('wally122.mem.used-wally124.mem.used', 4931),
#  ('wally113.mem.used-wally124.mem.used', 4930),
#  ('wally113.mem.used-wally122.mem.used', 4929),
#  ('wally117.mem.used-wally123.mem.used', 4929),
#  ('wally117.mem.used-wally124.mem.used', 4929),
#  ('wally122.mem.used-wally123.mem.used', 4928),
#  ('wally123.mem.used-wally124.mem.used', 4928),
#  ('wally113.mem.used-wally123.mem.used', 4926),
#  ('wally113.mem.used-wally117.mem.used', 4924),
#  ('wally122.cpu.user-wally124.mem.used', 2425),
#  ('wally122.cpu.user-wally122.mem.used', 2415),
#  ('wally117.cpu.user-wally124.mem.used', 2392),
#  ('wally117.cpu.user-wally122.mem.used', 2357),
#  ('wally117.cpu.user-wally117.mem.used', 2353),
#  ('wally124.cpu.user-wally124.mem.used', 2348),
#  ('wally117.mem.used-wally122.cpu.user', 2339),
#  ('wally122.cpu.user-wally123.mem.used', 2307),
# ...

# %%
reward.get_top_L_rank_count_for_arms(50)
# Out:
# A total of 159 different arms atleast once receive a reward within the top-50
# [('wally113.cpu.user-wally113.mem.used', 4931),
#  ('wally113.cpu.user-wally117.cpu.user', 4931),
#  ('wally113.cpu.user-wally117.mem.used', 4931),
#  ('wally113.cpu.user-wally122.cpu.user', 4931),
#  ('wally113.cpu.user-wally122.mem.used', 4931),
#  ('wally113.cpu.user-wally123.cpu.user', 4931),
#  ('wally113.cpu.user-wally123.mem.used', 4931),
#  ('wally113.cpu.user-wally124.cpu.user', 4931),
#  ('wally113.cpu.user-wally124.mem.used', 4931),
#  ('wally113.mem.used-wally117.cpu.user', 4931),
#  ('wally113.mem.used-wally117.mem.used', 4931),
#  ('wally113.mem.used-wally122.cpu.user', 4931),
#  ('wally113.mem.used-wally122.mem.used', 4931),
#  ('wally113.mem.used-wally123.cpu.user', 4931),
#  ('wally113.mem.used-wally123.mem.used', 4931),
#  ('wally113.mem.used-wally124.cpu.user', 4931),
#  ('wally113.mem.used-wally124.mem.used', 4931),
#  ('wally117.cpu.user-wally117.mem.used', 4931),
# ...

# %%
reward.get_top_L_rank_count_for_arms(100)
# Out:
# A total of 233 different arms atleast once receive a reward within the top-100
# [('wally113.cpu.user-wally113.mem.used', 4931),
#  ('wally113.cpu.user-wally117.cpu.user', 4931),
#  ('wally113.cpu.user-wally117.mem.used', 4931),
#  ('wally113.cpu.user-wally122.cpu.user', 4931),
#  ('wally113.cpu.user-wally122.mem.used', 4931),
#  ('wally113.cpu.user-wally123.cpu.user', 4931),
#  ('wally113.cpu.user-wally123.mem.used', 4931),
#  ('wally113.cpu.user-wally124.cpu.user', 4931),
#  ('wally113.cpu.user-wally124.mem.used', 4931),
#  ('wally113.mem.used-wally117.cpu.user', 4931),
#  ('wally113.mem.used-wally117.mem.used', 4931),
#  ('wally113.mem.used-wally122.cpu.user', 4931),
#  ('wally113.mem.used-wally122.mem.used', 4931),
#  ('wally113.mem.used-wally123.cpu.user', 4931),
#  ('wally113.mem.used-wally123.mem.used', 4931),
#  ('wally113.mem.used-wally124.cpu.user', 4931),
#  ('wally113.mem.used-wally124.mem.used', 4931),
#  ('wally117.cpu.user-wally117.mem.used', 4931),
# ...

# %%
reward.get_average_reward()
# Out:
# [('wally122.mem.used-wally124.mem.used', 0.9973471030971165),
#  ('wally117.mem.used-wally124.mem.used', 0.9973282786096859),
#  ('wally117.mem.used-wally122.mem.used', 0.9969664325248),
#  ('wally123.mem.used-wally124.mem.used', 0.9964985495843064),
#  ('wally122.mem.used-wally123.mem.used', 0.9961201717576167),
#  ('wally117.mem.used-wally123.mem.used', 0.9961013472701861),
#  ('wally113.mem.used-wally124.mem.used', 0.9958698551367842),
#  ('wally113.mem.used-wally122.mem.used', 0.9954749455682904),
#  ('wally113.mem.used-wally117.mem.used', 0.9954561210808598),
#  ('wally113.mem.used-wally123.mem.used', 0.9946263920554805),
#  ('wally122.cpu.user-wally124.mem.used', 0.9459881716231205),
#  ('wally122.cpu.user-wally122.mem.used', 0.9456180596673327),
#  ('wally117.mem.used-wally122.cpu.user', 0.945590969309),
#  ('wally117.cpu.user-wally124.mem.used', 0.9455466030795908),
#  ('wally117.cpu.user-wally122.mem.used', 0.9451572040916983),
# ...
