# %%
# Experiments for non-contextual bandit algorithms

# %%
import pdb
import sys
sys.path.append("../../src")
sys.path.append("../../src/models")
from collections import Counter
from experiment import perform_experiment_for_L, perform_experiment_for_Ls, perform_top_L_experiment_for_Ls, get_cross_validated_policies

# %%
#############
# Rewardfunction: continous

# %%
Ls = [5,10,20,50,100]

# %%
config_for_policy = {'name': 'cdkegreedy', 'context_path': '../../data/processed/context_push_active_hosts.csv'}
params = {'epsilon': [0.0, 0.05, 0.1], 'alpha': [1.1, 1.25, 1.5], 'q': [10, 20, 50]}
policies = get_cross_validated_policies(config_for_policy, params)
policies.append({'name': 'egreedy', 'epsilon': 0.01})
policies.append({'name': 'greedy'})
config = {
'reward_path' : '../../data/processed/seq_rewards_w30_s5_MI_n1.csv',    
'seed': 0,
'policies': policies
}

# %%
perform_experiment_for_Ls(config,Ls)
# Out:
# Experiment: Pick 5 arms out of 435
# A total of 29 different policies were evaluated
# 29. 1.25-cdk-0.1-dkgreedy-50, total regret: 11774.547346
# 28. 1.5-cdk-dkgreedy-50, total regret: 11449.737090
# 27. 1.5-cdk-0.05-dkgreedy-50, total regret: 11414.060424
# 26. 1.25-cdk-dkgreedy-50, total regret: 11316.035649
# 25. 1.5-cdk-0.05-dkgreedy-20, total regret: 11175.968227
# 24. 1.5-cdk-0.1-dkgreedy-50, total regret: 11141.570220
# 23. 1.5-cdk-0.1-dkgreedy-20, total regret: 11118.158703
# 22. 1.25-cdk-0.05-dkgreedy-50, total regret: 10818.671361
# 21. 1.5-cdk-dkgreedy-20, total regret: 9480.684622
# 20. 1.1-cdk-0.1-dkgreedy-50, total regret: 4496.382369
# 19. 1.1-cdk-0.05-dkgreedy-50, total regret: 4435.235112
# 18. 1.25-cdk-0.1-dkgreedy-20, total regret: 3899.781815
# 17. 1.1-cdk-dkgreedy-50, total regret: 3436.452581
# 16. 1.25-cdk-0.1-dkgreedy-10, total regret: 2903.653809
# 15. 1.5-cdk-0.1-dkgreedy-10, total regret: 2830.380184
# 14. 1.1-cdk-0.1-dkgreedy-20, total regret: 2684.037567
# ...

# %%
# Lets rerun the experiment and use pearson correlation as measure of correlation
config = config | {'reward_path' : '../../data/processed/seq_rewards_w30_s5_pear_n0.csv'}
perform_experiment_for_Ls(config,Ls)

# %%
# Lets perform the same experiments for the concurrent data as well
config = config | {'reward_path' : '../../data/processed/con_rewards_w30_s5_MI_n1.csv'}
perform_experiment_for_Ls(config,Ls)

# %%
# Pearson correlation as measure of correlation
config = config | {'reward_path' : '../../data/processed/con_rewards_w30_s5_pear_n0.csv'}
perform_experiment_for_Ls(config,Ls)

# %%
#############
# Rewardfunction: threshold

# %%
# 0.6
config |= {'reward_path': '../../data/processed/seq_rewards_w30_s5_MI_n1_threshold_0.6.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/con_rewards_w30_s5_MI_n1_threshold_0.6.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/seq_rewards_w30_s5_pear_n0_threshold_0.6.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/con_rewards_w30_s5_pear_n0_threshold_0.6.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
# 0.7
config |= {'reward_path': '../../data/processed/seq_rewards_w30_s5_MI_n1_threshold_0.7.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/con_rewards_w30_s5_MI_n1_threshold_0.7.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/seq_rewards_w30_s5_pear_n0_threshold_0.7.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/con_rewards_w30_s5_pear_n0_threshold_0.7.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
# 0.8
config |= {'reward_path': '../../data/processed/seq_rewards_w30_s5_MI_n1_threshold_0.8.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/con_rewards_w30_s5_MI_n1_threshold_0.8.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/seq_rewards_w30_s5_pear_n0_threshold_0.8.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
config |= {'reward_path': '../../data/processed/con_rewards_w30_s5_pear_n0_threshold_0.8.csv'}
perform_experiment_for_Ls(config, Ls)

# %%
#############
# Rewardfunction: top-L

# %%
reward_filepath = '../../data/processed/seq_rewards_w30_s5_MI_n1_top_%s.csv'
Ls = [5,10,20]
perform_top_L_experiment_for_Ls(config, reward_filepath, Ls)

# %%
reward_filepath = '../../data/processed/con_rewards_w30_s5_MI_n1_top_%s.csv'
perform_top_L_experiment_for_Ls(config, reward_filepath, Ls)

# %%
reward_filepath = '../../data/processed/seq_rewards_w30_s5_pear_n0_top_%s.csv'
perform_top_L_experiment_for_Ls(config, reward_filepath, Ls)

# %%
reward_filepath = '../../data/processed/con_rewards_w30_s5_pear_n0_top_%s.csv'
perform_top_L_experiment_for_Ls(config, reward_filepath, Ls)
